# %% [markdown]
# <a href="https://colab.research.google.com/github/vashic/Object-Detection/blob/master/YOLO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/RituAnilkumar/YOLO_Helper.git
# Out:
# Cloning into 'YOLO_Helper'...
# remote: Enumerating objects: 471, done.
# remote: Total 471 (delta 0), reused 0 (delta 0), pack-reused 471
# Receiving objects: 100% (471/471), 34.10 MiB | 24.50 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %%
# !pip3 install -r YOLO_Helper/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.1MB 8.0MB/s
# ...
#      |████████████████████████████████| 6.2MB 50.1MB/s
# ...
#      |████████████████████████████████| 51kB 9.0MB/s
# ...
#   Found existing installation: botocore 1.16.13
#     Uninstalling botocore-1.16.13:
#       Successfully uninstalled botocore-1.16.13
#   Found existing installation: rsa 4.0
#     Uninstalling rsa-4.0:
#       Successfully uninstalled rsa-4.0
# ...

# %%
# !python YOLO_Helper/main.py downloader --classes Apple  --type_csv  train --limit 300 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Apple'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 58404 KB/s, 0 seconds passed
# ...

# %%
# %cd YOLO_Helper/
# Out:
# /content/YOLO_Helper

# %%
# !python convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Apple
# 100% 300/300 [00:14<00:00, 20.78it/s]
# Converting annotations for class:  Elephant
# 0it [00:00, ?it/s]
# Converting annotations for class:  Elephant_Giraffe
# 0it [00:00, ?it/s]

# %%
# %cd ..
# Out:
# /content

# %%
# !rm -r OID/Dataset/train/Apple/Label/

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 13572 (delta 0), reused 0 (delta 0), pack-reused 13567
# Receiving objects: 100% (13572/13572), 12.20 MiB | 12.09 MiB/s, done.
# Resolving deltas: 100% (9254/9254), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ...

# %%
# !mv ../OID/Dataset/train/Apple ../OID/Dataset/train/obj

# %%
# !mv ../OID/Dataset/train/obj data/

# %%
# !python ../YOLO_Helper/generate_train.py

# %%
# !mv ../YOLO_Helper/obj.data data/
# !mv ../YOLO_Helper/obj.names data/
# !mv ../YOLO_Helper/yolov3_custom.cfg cfg/

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/darknet /content/check
# !ls /content/check
# Out:
# 3rdparty		darknet_video.py       results
# build			data		       scripts
# build.ps1		image_yolov2.sh        src
# build.sh		image_yolov3.sh        video_v2.sh
# cfg			include		       video_yolov3.sh
# cmake			json_mjpeg_streams.sh  yolov3_1000.weights
# CMakeLists.txt		LICENSE		       yolov3_custom_final.weights
# darknet			Makefile	       yolov3_final.weights
# DarknetConfig.cmake.in	net_cam_v3.sh	       yolov3_last.weights
# darknet.py		README.md

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-05-30 06:46:43--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   598KB/s    in 5m 31s
#
# 2020-05-30 06:52:16 (731 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg  yolov3.weights -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_custom
#  0 : compute_capability = 610, cudnn_half = 0, GPU: Tesla P4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !./darknet detect cfg/yolov3_custom.cfg /content/check/yolov3_custom_final.weights data/obj.data -dont-show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 610, cudnn_half = 0, GPU: Tesla P4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...
